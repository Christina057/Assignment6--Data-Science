# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("heart (1).csv")
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  slope  thal  target
# 0      52    1   0       125   212    0        1      2     3       0
# 1      53    1   0       140   203    1        0      0     3       0
# 2      70    1   0       145   174    0        1      0     3       0
# 3      61    1   0       148   203    0        1      2     3       0
# 4      62    0   0       138   294    1        1      1     2       0
# ...   ...  ...  ..       ...   ...  ...      ...    ...   ...     ...
# 1020   59    1   1       140   221    0        1      2     2       1
# 1021   60    1   0       125   258    0        0      1     3       0
# 1022   47    1   0       110   275    0        0      1     2       0
# 1023   50    0   0       110   254    0        0      2     2       1
# 1024   54    1   0       120   188    0        1      1     3       0
#
# [1025 rows x 10 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1020     True
# 1021     True
# 1022     True
# 1023     True
# 1024     True
# Length: 1025, dtype: bool

# %%
s=df.drop_duplicates()
s
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  slope  thal  target
# 0     52    1   0       125   212    0        1      2     3       0
# 1     53    1   0       140   203    1        0      0     3       0
# 2     70    1   0       145   174    0        1      0     3       0
# 3     61    1   0       148   203    0        1      2     3       0
# 4     62    0   0       138   294    1        1      1     2       0
# ..   ...  ...  ..       ...   ...  ...      ...    ...   ...     ...
# 723   68    0   2       120   211    0        0      1     2       1
# 733   44    0   2       108   141    0        1      1     2       1
# 739   52    1   0       128   255    0        1      2     3       0
# 843   59    1   3       160   273    0        0      2     2       0
# 878   54    1   0       120   188    0        1      1     3       0
#
# [302 rows x 10 columns]

# %%
print(s.loc[438])
# Out:
# age          47
# sex           1
# cp            2
# trestbps    130
# chol        253
# fbs           0
# restecg       1
# slope         2
# thal          2
# target        1
# Name: 438, dtype: int64

# %%
print(df.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  slope  thal  target
# 0   52    1   0       125   212    0        1      2     3       0
# 1   53    1   0       140   203    1        0      0     3       0
# 2   70    1   0       145   174    0        1      0     3       0
# 3   61    1   0       148   203    0        1      2     3       0
# 4   62    0   0       138   294    1        1      1     2       0

# %%
sb=df.sort_values('trestbps')
sb
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  slope  thal  target
# 223   39    0   2        94   199    0        1      2     2       1
# 301   51    1   2        94   227    0        1      2     3       1
# 732   51    1   2        94   227    0        1      2     3       1
# 704   51    1   2        94   227    0        1      2     3       1
# 558   39    0   2        94   199    0        1      2     2       1
# ..   ...  ...  ..       ...   ...  ...      ...    ...   ...     ...
# 326   54    1   1       192   283    0        0      2     3       0
# 508   56    0   0       200   288    1        0      0     3       0
# 294   56    0   0       200   288    1        0      0     3       0
# 688   56    0   0       200   288    1        0      0     3       0
# 175   56    0   0       200   288    1        0      0     3       0
#
# [1025 rows x 10 columns]

# %%
a=sb['trestbps'].median()
a
# Out:
# 130.0

# %%
b=df['chol'].min()
b
# Out:
# 126

# %%
c=df['chol'].max()
c
# Out:
# 564

# %%
rang=c-b
rang
# Out:
# 438

# %%
### doub

# %%
from scipy.stats import skew, kurtosis
skewness=skew(df)
skewness
# Out:
# array([-0.24850156, -0.85020237,  0.52868008,  0.7386852 ,  1.07250033,
#         1.96845247,  0.18017624, -0.47843296, -0.52362206, -0.05270121])

# %%
print(skew(df, axis=0, bias=True))
# Out:
# [-0.24850156 -0.85020237  0.52868008  0.7386852   1.07250033  1.96845247
#   0.18017624 -0.47843296 -0.52362206 -0.05270121]

# %%
kurto=kurtosis(df)
kurto
# Out:
# array([-0.52890528, -1.27715593, -1.14974781,  0.98054417,  3.97148511,
#         1.87480512, -1.30908183, -0.64982473,  0.24375671, -1.99722258])

# %%
print(kurtosis(df, axis=0, bias=True))
# Out:
# [-0.52890528 -1.27715593 -1.14974781  0.98054417  3.97148511  1.87480512
#  -1.30908183 -0.64982473  0.24375671 -1.99722258]

# %%
import matplotlib.pyplot as plt
plt.boxplot(s['trestbps'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fa685c9b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fa685d8130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fa685c99a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fa685d8700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fa685d89d0>],
#  'means': []}

# %%
print(sb['fbs'].corr(sb['trestbps']))
# Out:
# 0.18176662350423886

# %%
import matplotlib.pyplot as plt

plt.scatter(sb['fbs'], sb['trestbps'])

plt.title("Scatter Plot")

plt.xlabel('')
plt.ylabel('')

plt.colorbar()

plt.show()

# %%
import plotly.express as px

fig = px.area(sb, x ='age', y = 'chol')

fig.show()
# Out:
# <div>                            <div id="d7bcddb6-0d42-41e6-a674-6cff2ab4530b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7bcddb6-0d42-41e6-a674-6cff2ab4530b")) {                    Plotly.newPlot(                        "d7bcddb6-0d42-41e6-a674-6cff2ab4530b",                        [{"fillpattern":{"shape":""},"hovertemplate":"age=%{x}<br>chol=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"stackgroup":"1","x":[39,51,51,51,39,51,39,67,67,58,67,58,58,58,51,58,58,51,58,51,51,46,46,46,60,60,42,60,42,42,45,45,45,46,46,58,58,46,41,41,58,41,67,67,67,63,47,52,63,54,63,54,54,54,54,44,44,47,52,54,52,44,54,47,63,47,64,45,44,59,41,41,54,54,57,71
# ...

# %%
plt.hist(sb['age'])

plt.title("Histogram")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('tips')
sns.pairplot(df, hue ='sex')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('tips')
sns.pairplot(df, hue ='day')
plt.show()
